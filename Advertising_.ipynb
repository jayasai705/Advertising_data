# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('advertising.csv')
data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0   2016-03-27 0:53:11              0
# 1   2016-04-04 1:39:02              0
# 2  2016-03-13 20:35:42              0
# 3   2016-01-10 2:31:19              0
# 4   2016-06-03 3:36:18              0

# %%
data.City.value_counts()
# Out:
# Lisamouth         3
# Williamsport      3
# Wrightburgh       2
# Lake Jose         2
# Robertfurt        2
#                  ..
# Burgessside       1
# Hurleyborough     1
# Garychester       1
# East Kevinbury    1
# Ronniemouth       1
# Name: City, Length: 969, dtype: int64

# %%
import seaborn as sns
sns.countplot(x = data.City)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.countplot(x = data.Country)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
data.Country.value_counts().describe()
# Out:
# count    237.000000
# mean       4.219409
# std        1.837222
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max        9.000000
# Name: Country, dtype: float64

# %%
data.Timestamp.dtype
# Out:
# dtype('O')

# %%
dates = pd.to_datetime(data.Timestamp)

# %%
def hour(time):
    return time.hour
data['hour'] = dates.apply(hour)
# data.Timestamp.apply(lambda x:x.hour)

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad  hour
# 0   2016-03-27 0:53:11              0     0
# 1   2016-04-04 1:39:02              0     1
# 2  2016-03-13 20:35:42              0    20
# 3   2016-01-10 2:31:19              0     2
# 4   2016-06-03 3:36:18              0     3

# %%
data['min'] = dates.apply(lambda x:x.minute)

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad  hour  min
# 0   2016-03-27 0:53:11              0     0   53
# 1   2016-04-04 1:39:02              0     1   39
# 2  2016-03-13 20:35:42              0    20   35
# 3   2016-01-10 2:31:19              0     2   31
# 4   2016-06-03 3:36:18              0     3   36

# %%
X = data.drop(['Clicked on Ad', 'City', 'Ad Topic Line', 'Timestamp'],axis=1)
y = data['Clicked on Ad']

# %%
X
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#                     Country  hour  min
# 0                   Tunisia     0   53
# 1                     Nauru     1   39
# 2                San Marino    20   35
# 3                     Italy     2   31
# 4                   Iceland     3   36
# ..                      ...   ...  ...
# 995                 Lebanon    21   49
# 996  Bosnia and Herzegovina     2    7
# 997                Mongolia    17   24
# 998               Guatemala     2   35
# 999                  Brazil    21   43
#
# [1000 rows x 8 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Clicked on Ad, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train.iloc[:, :4] = sc.fit_transform(X_train.iloc[:, :4])
X_test.iloc[:, :4] = sc.transform(X_test.iloc[:, :4])
X_train.iloc[:, 6:] = sc.fit_transform(X_train.iloc[:, 6:])
X_test.iloc[:, 6:] = sc.transform(X_test.iloc[:, 6:])
# Out:
# C:\Users\JAYA SAI KRISHNA\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\JAYA SAI KRISHNA\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\JAYA SAI KRISHNA\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\JAYA SAI KRISHNA\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
X_train
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 559                  0.865414 -0.571682     0.390998              1.270634
# 313                  0.457991 -0.343636     0.466258              1.612286
# 699                  0.564742 -0.799727     0.605481              1.232774
# 576                 -1.761675  0.340500    -0.408920             -0.825750
# 747                 -0.998625 -0.457659    -1.065029             -1.331766
# ..                        ...       ...          ...                   ...
# 928                  0.984798 -0.799727     0.851009              0.190589
# 849                 -0.372015  1.822796    -0.382864             -1.378015
# 460                 -1.068108  0.454523    -2.241188             -1.011879
# 621                  1.447176 -0.571682    -0.224043              0.703633
# 458                 -0.003755  0.682569     1.128794             -1.120699
#
#      Male              Country      hour       min
# 559     1            Nicaragua  0.756567  1.554569
# 313     1          Saint Lucia -0.107464 -0.751486
# 699     0         Saint Helena -0.827490  0.459193
# 576     1  Antigua and Barbuda -0.971495  1.035707
# 747     0                 Fiji -1.691520  0.920404
# ..    ...                  ...       ...       ...
# 928     0            Singapore -0.539479 -0.924440
# 849     1               Uganda -1.259505  0.978056
# 460     1                Malta  1.476593 -0.751486
# 621     1     French Polynesia  1.044577  1.093358
# 458     1    Equatorial Guinea  1.476593 -0.347926
#
# [800 rows x 8 columns]

# %%
X_test
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 793                 -1.788837 -0.457659    -0.304413             -0.380719
# 304                 -1.984652  0.796591    -0.981974             -0.309986
# 715                 -0.994835  0.226478     0.445717             -1.273048
# 51                   0.947530 -0.913750     0.257629              1.044151
# 131                 -1.469847 -0.001568    -0.099734             -1.058354
# ..                        ...       ...          ...                   ...
# 771                 -0.035338 -1.939954    -0.197397              0.028039
# 300                  0.317762 -0.913750    -0.006802              1.604351
# 873                  0.457991 -0.457659     0.450504              1.611606
# 953                 -1.226024 -0.799727     0.075788             -0.853635
# 617                  0.219222  0.226478     0.477869              1.825620
#
#      Male                        Country      hour       min
# 793     1                         Poland  1.044577  1.727523
# 304     0                       Cambodia  1.332588  1.439266
# 715     0                        Hungary  0.036541 -1.039742
# 51      0                 United Kingdom  1.332588 -0.578532
# 131     0                   Saint Martin  0.900572  1.208661
# ..    ...                            ...       ...       ...
# 771     1                          Gabon -0.971495 -0.347926
# 300     0  Holy See (Vatican City State) -1.691520 -1.616256
# 873     1                    Switzerland  1.044577  0.920404
# 953     0           United Arab Emirates  1.476593 -1.616256
# 617     0                  Guinea-Bissau  0.468557 -0.117321
#
# [200 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_train.Country = np.array(le.fit_transform(X_train.Country))
# Out:
# C:\Users\JAYA SAI KRISHNA\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_test.Country = np.array(le.fit_transform(X_test.Country))

# %%
X_train
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 559                  0.865414 -0.571682     0.390998              1.270634
# 313                  0.457991 -0.343636     0.466258              1.612286
# 699                  0.564742 -0.799727     0.605481              1.232774
# 576                 -1.761675  0.340500    -0.408920             -0.825750
# 747                 -0.998625 -0.457659    -1.065029             -1.331766
# ..                        ...       ...          ...                   ...
# 928                  0.984798 -0.799727     0.851009              0.190589
# 849                 -0.372015  1.822796    -0.382864             -1.378015
# 460                 -1.068108  0.454523    -2.241188             -1.011879
# 621                  1.447176 -0.571682    -0.224043              0.703633
# 458                 -0.003755  0.682569     1.128794             -1.120699
#
#      Male  Country      hour       min
# 559     1      152  0.756567  1.554569
# 313     1      178 -0.107464 -0.751486
# 699     0      176 -0.827490  0.459193
# 576     1        8 -0.971495  1.035707
# 747     0       67 -1.691520  0.920404
# ..    ...      ...       ...       ...
# 928     0      190 -0.539479 -0.924440
# 849     1      218 -1.259505  0.978056
# 460     1      129  1.476593 -0.751486
# 621     1       71  1.044577  1.093358
# 458     1       61  1.476593 -0.347926
#
# [800 rows x 8 columns]

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[100   3]
#  [  3  94]]
# 0.97
